# %%
import numpy as np
import pandas as pd
import json
import requests
from pandas.io.json import json_normalize
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
import folium
print ('libraries imported')
# Out:
# libraries imported

# %%
pip install lxml
# Out:
# ...
#      |████████████████████████████████| 5.5MB 7.1MB/s eta 0:00:0101
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install geocoder
# Out:
# ...
#      |████████████████████████████████| 102kB 5.8MB/s ta 0:00:011
# ...
#      |████████████████████████████████| 829kB 8.3MB/s eta 0:00:01
# ...
#   Using cached https://files.pythonhosted.org/packages/d2/3d/fa76db83bf75c4f8d338c2fd15c8d33fdd7ad23a9b5e57eb6c5de26b430e/click-7.1.2-py2.py3-none-any.whl
# ...
#   Stored in directory: /home/jupyterlab/.cache/pip/wheels/8b/99/a0/81daf51dcd359a9377b110a8a886b3895921802d2fc1b2397e
# Successfully built future
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
data=pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')

# %% [markdown]
# #View the tables to figure out which one i need.

# %%
df=data[0]
df
# Out:
#     Postal Code           Borough  \
# 0           M1A      Not assigned
# 1           M2A      Not assigned
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# ..          ...               ...
# 175         M5Z      Not assigned
# 176         M6Z      Not assigned
# 177         M7Z      Not assigned
# 178         M8Z         Etobicoke
# 179         M9Z      Not assigned
#
#                                          Neighbourhood
# 0                                         Not assigned
# 1                                         Not assigned
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                            Regent Park, Harbourfront
# ..                                                 ...
# 175                                       Not assigned
# 176                                       Not assigned
# ...

# %% [markdown]
# #Only process the cells that have an assigned borough. Ignore cells with a borough that is Not assigned.

# %%
df2=df[df.Borough != 'Not assigned']
df2
# Out:
#     Postal Code           Borough  \
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# 5           M6A        North York
# 6           M7A  Downtown Toronto
# ..          ...               ...
# 160         M8X         Etobicoke
# 165         M4Y  Downtown Toronto
# 168         M7Y      East Toronto
# 169         M8Y         Etobicoke
# 178         M8Z         Etobicoke
#
#                                          Neighbourhood
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                            Regent Park, Harbourfront
# 5                     Lawrence Manor, Lawrence Heights
# 6          Queen's Park, Ontario Provincial Government
# ..                                                 ...
# 160      The Kingsway, Montgomery Road, Old Mill North
# 165                               Church and Wellesley
# ...

# %% [markdown]
# #In the last cell of your notebook, use the .shape method to print the number of rows of your dataframe.

# %%
df2.shape
# Out:
# (103, 3)

# %% [markdown]
# #PART 2 of the Week 3 Final

# %%
dfCoord=pd.read_csv('https://cocl.us/Geospatial_data')
dfCoord
# Out:
#     Postal Code   Latitude  Longitude
# 0           M1B  43.806686 -79.194353
# 1           M1C  43.784535 -79.160497
# 2           M1E  43.763573 -79.188711
# 3           M1G  43.770992 -79.216917
# 4           M1H  43.773136 -79.239476
# ..          ...        ...        ...
# 98          M9N  43.706876 -79.518188
# 99          M9P  43.696319 -79.532242
# 100         M9R  43.688905 -79.554724
# 101         M9V  43.739416 -79.588437
# 102         M9W  43.706748 -79.594054
#
# [103 rows x 3 columns]

# %%
dfP3=pd.merge(df2,dfCoord, how='inner', on=None, left_on=None,right_on=None,
         left_index=False, right_index=False, sort=True,
         suffixes=('_x', '_y'), copy=True, indicator=False,
         validate=None)
dfP3
# Out:
#     Postal Code      Borough  \
# 0           M1B  Scarborough
# 1           M1C  Scarborough
# 2           M1E  Scarborough
# 3           M1G  Scarborough
# 4           M1H  Scarborough
# ..          ...          ...
# 98          M9N         York
# 99          M9P    Etobicoke
# 100         M9R    Etobicoke
# 101         M9V    Etobicoke
# 102         M9W    Etobicoke
#
#                                          Neighbourhood   Latitude  Longitude
# 0                                       Malvern, Rouge  43.806686 -79.194353
# 1               Rouge Hill, Port Union, Highland Creek  43.784535 -79.160497
# 2                    Guildwood, Morningside, West Hill  43.763573 -79.188711
# 3                                               Woburn  43.770992 -79.216917
# 4                                            Cedarbrae  43.773136 -79.239476
# ..                                                 ...        ...        ...
# ...

# %% [markdown]
# #<b>PART 3 of the Week 3 Final</b>

# %%
pip install geopandas
# Out:
# ...
#      |████████████████████████████████| 972kB 8.4MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 10.9MB 33.2MB/s eta 0:00:01    |██████████████████▍             | 6.3MB 33.2MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.0MB 32.9MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 14.8MB 7.2MB/s eta 0:00:011
# ...
#   Found existing installation: pyproj 1.9.6
#     Uninstalling pyproj-1.9.6:
#       Successfully uninstalled pyproj-1.9.6
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install geopy
# Out:
# ...
#      |████████████████████████████████| 112kB 8.1MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from geopy.geocoders import Nominatim

# %%
latitude=dfP3.Latitude
longitude=dfP3.Longitude

# %%
geolocator = Nominatim(user_agent="mygeocoder")
location = geolocator.geocode('Toronto, CA')
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto, Canada are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto, Canada are 43.6534817, -79.3839347.

# %%
dfP3map=folium.Map(location=[43.6532, -79.3832], zoom_start=13)
dfP3map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
dfP3.dtypes
# Out:
# Postal Code       object
# Borough           object
# Neighbourhood     object
# Latitude         float64
# Longitude        float64
# dtype: object

# %%
dfP3map = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(dfP3['Latitude'], dfP3['Longitude'], dfP3['Borough'], dfP3['Neighbourhood']):
    label = '{}, {}'.format(dfP3.Neighbourhood, dfP3.Borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#fc03e8',
        fill_opacity=0.7,
        parse_html=False).add_to(dfP3map)  
    
dfP3map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
CLIENT_ID = 'HHNAWSHJTNB3I0QFAPEBMMF5XVXDNMUVJ5D1MELGUBLJI3K5' # your Foursquare ID
CLIENT_SECRET = 'UKCMJR4HPEKIEDDZTUWKDQM0D51R4004KPEV51PVK4ZS3J0D' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT=30

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: HHNAWSHJTNB3I0QFAPEBMMF5XVXDNMUVJ5D1MELGUBLJI3K5
# CLIENT_SECRET:UKCMJR4HPEKIEDDZTUWKDQM0D51R4004KPEV51PVK4ZS3J0D

# %%
geolocator = Nominatim(user_agent="fourquare_agent")
location = geolocator.geocode('Toronto, CA')
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto, Canada are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto, Canada are 43.6534817, -79.3839347.

# %%
search_query = 'Hotel'
radius = 500
print(search_query + ' .... OK!')
# Out:
# Hotel .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=HHNAWSHJTNB3I0QFAPEBMMF5XVXDNMUVJ5D1MELGUBLJI3K5&client_secret=UKCMJR4HPEKIEDDZTUWKDQM0D51R4004KPEV51PVK4ZS3J0D&ll=43.6534817,-79.3839347&v=20180605&query=Hotel&radius=500&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5f4e75b1ad557739b7dfa47c'},
#  'response': {'venues': [{'id': '4ab2d511f964a5209b6c20e3',
#     'name': 'Sheraton Centre Toronto Hotel',
#     'location': {'address': '123 Queen Street West',
#      'crossStreet': 'at York St.',
#      'lat': 43.6505944,
#      'lng': -79.3845298,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6505944,
#        'lng': -79.3845298}],
#      'distance': 324,
#      'postalCode': 'M5H 2M9',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['123 Queen Street West (at York St.)',
#       'Toronto ON M5H 2M9',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
# ...

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = pd.json_normalize(venues)
dataframe.head()
# Out:
#                          id                             name  \
# 0  4ab2d511f964a5209b6c20e3    Sheraton Centre Toronto Hotel
# 1  4af96fbbf964a520c01122e3  One King West Hotel & Residence
# 2  51d212c3498ebf27dc469bc9                    Chelsea Hotel
# 3  4ae61cf6f964a520caa421e3             Pantages Hotel & Spa
# 4  51e48697498eded9073c6c17    Crew Room Eaton Chelsea Hotel
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1598977713    False
# 1  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1598977713    False
# 2  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1598977713    False
# 3  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1598977713    False
# 4  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1598977713    False
#
#          location.address location.crossStreet  location.lat  location.lng  \
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered.head()
# Out:
#                               name categories                 address  \
# 0    Sheraton Centre Toronto Hotel      Hotel   123 Queen Street West
# 1  One King West Hotel & Residence      Hotel             1 King St W
# 2                    Chelsea Hotel      Hotel  33 Gerrard Street West
# 3             Pantages Hotel & Spa      Hotel         200 Victoria St
# 4    Crew Room Eaton Chelsea Hotel      Hotel  33 Gerrard Street West
#
#     crossStreet        lat        lng  \
# 0   at York St.  43.650594 -79.384530
# 1  at Yonge St.  43.649139 -79.377876
# 2   at Yonge St  43.658498 -79.383097
# 3  at Shuter St  43.654498 -79.379035
# 4           NaN  43.658094 -79.382711
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 43.6505944, 'lng'...       324    M5H 2M9  CA
# 1  [{'label': 'display', 'lat': 43.6491395, 'lng'...       686    M5H 1A1  CA
# ...

# %%
dataframe_filtered.name
# Out:
# 0                      Sheraton Centre Toronto Hotel
# 1                    One King West Hotel & Residence
# 2                                      Chelsea Hotel
# 3                               Pantages Hotel & Spa
# 4                      Crew Room Eaton Chelsea Hotel
# 5                     The Rex Hotel Jazz & Blues Bar
# 6                                     VFM Test Hotel
# 7            Cosmopolitan Toronto Centre Hotel & Spa
# 8     Sheraton Centre Toronto Hotel - Grand Ballroom
# 9                                     St Regis Hotel
# 10                                   Stathcona Hotel
# 11                 Sheraton Centre Hotel Club Lounge
# 12                                    Pentagos hotel
# 13                  Shizen Spa at the Pantages Hotel
# 14                                Pantages Hotel Gym
# 15                                         650 Hotel
# 16                     Pantages Hotel Toronto Centre
# 17                                 Be SixFifty Hotel
# ...

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around the Toronto

# add a red circle marker to represent the city
folium.features.CircleMarker(
    [latitude, longitude],
    radius=5,
    color='red',
    popup='Downtown',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the museum as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=6,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
print(dataframe_filtered.shape)
dataframe_filtered.head()
# Out:
# (30, 15)
#                               name categories                 address  \
# 0    Sheraton Centre Toronto Hotel      Hotel   123 Queen Street West
# 1  One King West Hotel & Residence      Hotel             1 King St W
# 2                    Chelsea Hotel      Hotel  33 Gerrard Street West
# 3             Pantages Hotel & Spa      Hotel         200 Victoria St
# 4    Crew Room Eaton Chelsea Hotel      Hotel  33 Gerrard Street West
#
#     crossStreet        lat        lng  \
# 0   at York St.  43.650594 -79.384530
# 1  at Yonge St.  43.649139 -79.377876
# 2   at Yonge St  43.658498 -79.383097
# 3  at Shuter St  43.654498 -79.379035
# 4           NaN  43.658094 -79.382711
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 43.6505944, 'lng'...       324    M5H 2M9  CA
# 1  [{'label': 'display', 'lat': 43.6491395, 'lng'...       686    M5H 1A1  CA
# ...

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitude, longitude):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius=500, 
            LIMIT=50)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    print('Found {} venues in {} neighborhoods.'.format(nearby_venues.shape[0], len(venues_list)))
    
    return(nearby_venues)

# %%
toronto_venues = getNearbyVenues(names=dataframe_filtered['categories'],
                                   latitudes=dataframe_filtered['lat'],
                                   longitudes=dataframe_filtered['lng']
                                  )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-401-0773b1762567> in <module>
#       1 toronto_venues = getNearbyVenues(names=dataframe_filtered['categories'],
#       2                                    latitudes=dataframe_filtered['lat'],
# ----> 3                                    longitudes=dataframe_filtered['lng']
#       4                                   )
#
# <ipython-input-400-3f5293fc38cf> in getNearbyVenues(names, latitudes, longitudes, radius)
#       2
#       3     venues_list=[]
# ----> 4     for name, lat, lng in zip(names, latitude, longitude):
#       5         print(name)
#       6
#
# TypeError: zip argument #2 must support iteration
